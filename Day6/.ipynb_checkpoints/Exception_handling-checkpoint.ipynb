# %% [markdown]
# ## A calculator function

# %%
def calculator(operation,a,b):
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else: 
            return None

# %%
calculator('/',5,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-d6176e3a0f68> in <module>
# ----> 1 calculator('/',5,0)
#
# <ipython-input-1-2516a7f5d4e2> in calculator(operation, a, b)
#       7             return a*b
#       8         elif (operation=='div') or (operation=='/'):
# ----> 9             return a/b
#      10         else:
#      11             return None
#
# ZeroDivisionError: division by zero

# %%
calculator('+',5,'0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f233b8d72a2a> in <module>
# ----> 1 calculator('+',5,'0')
#
# <ipython-input-1-2516a7f5d4e2> in calculator(operation, a, b)
#       1 def calculator(operation,a,b):
#       2         if (operation == 'add') or (operation == '+'):
# ----> 3             return a+b
#       4         elif (operation=='sub') or (operation=='-'):
#       5             return a-b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Calculator function with try/except block

# %%
def calculator(operation,a,b):
    try:
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else: 
            return None
    except:
        print('There was an exception')

# %%
calculator('/',5,0)

# %%
calculator('+',5,'0')

# %% [markdown]
# ## Calculator function with try/except and exception message

# %%
def calculator(operation,a,b):
    try:
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else: 
            return None
    except Exception as inst:
        print(inst)

# %%
calculator('/',5,0)

# %%
calculator('+',5,'0')

# %% [markdown]
# ## Calculate function with single try and multiple exception

# %%
def calculator(operation,a,b):
    try:
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else:
            return None
    except ZeroDivisionError as ze:
        print(ze)
        print('Please enter a non zero value for the denominator')
    except TypeError as te:
        print(te)

# %%
calculator('/',5,0)

# %%
calculator('+',5,'0')

# %% [markdown]
# ## Calculate function with single try and mulitple exception along with user defined exception message

# %%
def calculator(operation,a,b):
    try:
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else:
            return None
    except ZeroDivisionError as e:
        print(e)
        print('Operation {} is not defined on {} & {}'.format(operation,a,b))
    except TypeError as e:
        print(e)
        print('Please provide valid inputs')

# %%
calculator('/',5,0)

# %%
calculator('+',5,'0')

# %% [markdown]
# ## Calculator function with raise exception

# %%
def calculator(operation,a,b):
    try:
        if (operation == 'add') or (operation == '+'):
            return a+b
        elif (operation=='sub') or (operation=='-'):
            return a-b
        elif (operation=='mul') or (operation=='*'):
            return a*b
        elif (operation=='div') or (operation=='/'):
            return a/b
        else:
            raise TypeError
    except ZeroDivisionError as e:
        print(e)
        print('Operation {} is not defined on {} & {}'.format(operation,a,b))
    except TypeError as e:
        print(e)
        print('Please provide valid inputs')

# %%
calculator('/',5,0)

# %%
calculator('+',5,'0')

# %%
calculator('+*',5,0)

# %% [markdown]
# ## Function to read files

# %%
def read_file(file):
    try:
        fh = open(file)
        raise TypeError
            
    except:
        print('Inside except block')
        print('Has the file {} closed : {}'.format(file,fh.closed)) 

    finally:
        fh.close()
        print('Inside finally block')
        print('Has the file {} closed : {}'.format(file,fh.closed))

# %%
read_file('mbox-short.txt')
